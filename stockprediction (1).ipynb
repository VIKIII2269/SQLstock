# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sqlalchemy import create_engine

# Replace these placeholders with your actual PostgreSQL credentials
db_engine = create_engine('postgresql+psycopg2://username:password@host:port/dbname')

# Example query to pull data
query = "SELECT * FROM your_table_name;"
df = pd.read_sql(query, db_engine)

# Now you can use the dataframe 'df' in your notebook


from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
# or directly import
df = pd.read_csv('GOOG.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
# shape of data
print("Shape of data:",df.shape)

# statistical description of data
df.describe()
# Out:
# Shape of data: (1258, 14)
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 5s 54ms/step - loss: 0.0080 - mean_absolute_error: 0.0635 - val_loss: 0.0114 - val_mean_absolute_error: 0.0843
# Epoch 2/100
# 28/28 [==============================] - 1s 30ms/step - loss: 9.8018e-04 - mean_absolute_error: 0.0249 - val_loss: 0.0074 - val_mean_absolute_error: 0.0707
# Epoch 3/100
# 28/28 [==============================] - 1s 30ms/step - loss: 5.0238e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0026 - val_mean_absolute_error: 0.0391
# Epoch 4/100
# 28/28 [==============================] - 1s 30ms/step - loss: 4.4483e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0031 - val_mean_absolute_error: 0.0433
# Epoch 5/100
# 28/28 [==============================] - 1s 30ms/step - loss: 4.3804e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0023 - val_mean_absolute_error: 0.0362
# Epoch 6/100
# 28/28 [==============================] - 1s 31ms/step - loss: 4.5308e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0023 - val_mean_absolute_error: 0.0359
# Epoch 7/100
# 28/28 [==============================] - 1s 30ms/step - loss: 4.1486e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0032 - val_mean_absolute_error: 0.0433
# Epoch 8/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.8721e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 9/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.8073e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 10/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.8857e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0031 - val_mean_absolute_error: 0.0428
# Epoch 11/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.8905e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0027 - val_mean_absolute_error: 0.0391
# Epoch 12/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.9930e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0034 - val_mean_absolute_error: 0.0454
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.2358e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0046 - val_mean_absolute_error: 0.0549
# Epoch 14/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.6348e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0030 - val_mean_absolute_error: 0.0421
# Epoch 15/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.3116e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0036 - val_mean_absolute_error: 0.0479
# Epoch 16/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.1687e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0034 - val_mean_absolute_error: 0.0456
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.9004e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0042 - val_mean_absolute_error: 0.0517
# Epoch 18/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.0715e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0050 - val_mean_absolute_error: 0.0578
# Epoch 19/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.1237e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 20/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.0856e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0039 - val_mean_absolute_error: 0.0501
# Epoch 21/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.1839e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0042 - val_mean_absolute_error: 0.0528
# Epoch 22/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.8341e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0023 - val_mean_absolute_error: 0.0367
# Epoch 23/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.8208e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0024 - val_mean_absolute_error: 0.0369
# Epoch 24/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.2741e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0035 - val_mean_absolute_error: 0.0466
# Epoch 25/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.9422e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0043 - val_mean_absolute_error: 0.0533
# Epoch 26/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.7400e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0029 - val_mean_absolute_error: 0.0423
# Epoch 27/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.9434e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0023 - val_mean_absolute_error: 0.0361
# Epoch 28/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.6390e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0028 - val_mean_absolute_error: 0.0409
# Epoch 29/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5539e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0033 - val_mean_absolute_error: 0.0446
# Epoch 30/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.4032e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0027 - val_mean_absolute_error: 0.0400
# Epoch 31/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5487e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0051 - val_mean_absolute_error: 0.0594
# Epoch 32/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.7452e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 33/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.4308e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0033 - val_mean_absolute_error: 0.0457
# Epoch 34/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.1754e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0032 - val_mean_absolute_error: 0.0443
# Epoch 35/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.2127e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0025 - val_mean_absolute_error: 0.0383
# Epoch 36/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.3824e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0029 - val_mean_absolute_error: 0.0422
# Epoch 37/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.2083e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0030 - val_mean_absolute_error: 0.0434
# Epoch 38/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.1443e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0023 - val_mean_absolute_error: 0.0368
# Epoch 39/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.0312e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0022 - val_mean_absolute_error: 0.0353
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.1377e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0025 - val_mean_absolute_error: 0.0385
# Epoch 41/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.3571e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0038 - val_mean_absolute_error: 0.0497
# Epoch 42/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.9407e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0023 - val_mean_absolute_error: 0.0358
# Epoch 43/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.0355e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0024 - val_mean_absolute_error: 0.0378
# Epoch 44/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.9421e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 45/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5893e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0034 - val_mean_absolute_error: 0.0468
# Epoch 46/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.2693e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0021 - val_mean_absolute_error: 0.0336
# Epoch 47/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.9457e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0027 - val_mean_absolute_error: 0.0401
# Epoch 48/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.8918e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351
# Epoch 49/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.9829e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 50/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.8354e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0032 - val_mean_absolute_error: 0.0446
# Epoch 51/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7683e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0027 - val_mean_absolute_error: 0.0405
# Epoch 52/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.8169e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0044 - val_mean_absolute_error: 0.0553
# Epoch 53/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7258e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0021 - val_mean_absolute_error: 0.0349
# Epoch 54/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7155e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0036 - val_mean_absolute_error: 0.0481
# Epoch 55/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7036e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0025 - val_mean_absolute_error: 0.0387
# Epoch 56/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6266e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0035 - val_mean_absolute_error: 0.0474
# Epoch 57/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6531e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0028 - val_mean_absolute_error: 0.0404
# Epoch 58/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5944e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0020 - val_mean_absolute_error: 0.0334
# Epoch 59/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6158e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0028 - val_mean_absolute_error: 0.0409
# Epoch 60/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6221e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0025 - val_mean_absolute_error: 0.0371
# Epoch 61/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5258e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0018 - val_mean_absolute_error: 0.0307
# Epoch 62/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5824e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0015 - val_mean_absolute_error: 0.0276
# Epoch 63/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5891e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0403
# Epoch 64/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7430e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0036 - val_mean_absolute_error: 0.0480
# Epoch 65/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5035e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0303
# Epoch 66/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5701e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0030 - val_mean_absolute_error: 0.0442
# Epoch 67/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3203e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0017 - val_mean_absolute_error: 0.0306
# Epoch 68/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3891e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0030 - val_mean_absolute_error: 0.0427
# Epoch 69/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.4921e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0304
# Epoch 70/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.5787e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0023 - val_mean_absolute_error: 0.0370
# Epoch 71/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.4169e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 72/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.4239e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0022 - val_mean_absolute_error: 0.0354
# Epoch 73/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3253e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388
# Epoch 74/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3090e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0030 - val_mean_absolute_error: 0.0430
# Epoch 75/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.2427e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0038 - val_mean_absolute_error: 0.0492
# Epoch 76/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2710e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0027 - val_mean_absolute_error: 0.0405
# Epoch 77/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3122e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0022 - val_mean_absolute_error: 0.0340
# Epoch 78/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.6698e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0012 - val_mean_absolute_error: 0.0252
# Epoch 79/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3135e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0029 - val_mean_absolute_error: 0.0424
# Epoch 80/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2838e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0039 - val_mean_absolute_error: 0.0515
# Epoch 81/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3215e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0023 - val_mean_absolute_error: 0.0364
# Epoch 82/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2144e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0020 - val_mean_absolute_error: 0.0330
# Epoch 83/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2617e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0025 - val_mean_absolute_error: 0.0390
# Epoch 84/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3296e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0018 - val_mean_absolute_error: 0.0318
# Epoch 85/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.2094e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0016 - val_mean_absolute_error: 0.0288
# Epoch 86/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3011e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0027 - val_mean_absolute_error: 0.0400
# Epoch 87/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2087e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0023 - val_mean_absolute_error: 0.0373
# Epoch 88/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2240e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0017 - val_mean_absolute_error: 0.0304
# Epoch 89/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.2720e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0026 - val_mean_absolute_error: 0.0402
# Epoch 90/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3129e-04 - mean_absolute_error: 0.0082 - val_loss: 8.8428e-04 - val_mean_absolute_error: 0.0221
# Epoch 91/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.2986e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0018 - val_mean_absolute_error: 0.0318
# Epoch 92/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.1201e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0032 - val_mean_absolute_error: 0.0447
# Epoch 93/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.0512e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0020 - val_mean_absolute_error: 0.0336
# Epoch 94/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.1027e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0025 - val_mean_absolute_error: 0.0384
# Epoch 95/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.0889e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 96/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.0186e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0034 - val_mean_absolute_error: 0.0461
# Epoch 97/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.1824e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0025 - val_mean_absolute_error: 0.0386
# Epoch 98/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.0357e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0030 - val_mean_absolute_error: 0.0426
# Epoch 99/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.2857e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0025 - val_mean_absolute_error: 0.0395
# Epoch 100/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.1663e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0023 - val_mean_absolute_error: 0.0370

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 12ms/step
# array([[0.40120706, 0.40681946],
#        [0.40032434, 0.4058276 ],
#        [0.3955851 , 0.40088454],
#        [0.39969453, 0.40483627],
#        [0.4030964 , 0.40821686]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1414.8058, 1422.2349],
#        [1413.1693, 1420.3965],
#        [1404.383 , 1411.2354],
#        [1412.0016, 1418.5592],
#        [1418.3085, 1424.8246]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1414.805786      1422.234863
# 2020-05-28  1396.86  1416.73     1413.169312      1420.396484
# 2020-05-29  1416.94  1428.92     1404.383057      1411.235352
# 2020-06-01  1418.39  1431.82     1412.001587      1418.559204
# 2020-06-02  1430.55  1439.22     1418.308472      1424.824585

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2278.111816      2358.135986
# 2021-06-10  2494.01  2521.60     2283.265137      2364.718018
# 2021-06-11  2524.92  2513.93     2293.669922      2375.794189
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %%
df.to_sql('processed_data_table', db_engine, if_exists='replace', index=False)#send results back
